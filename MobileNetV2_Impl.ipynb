# %% [markdown]
# <a href="https://colab.research.google.com/github/mcsantiago/MobileNetV2-Impl/blob/master/MobileNetV2_Impl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# select tensorflow 2 in colab
# %tensorflow_version 2.x

# install tensorflow 2 and tensorflow datasets on a personal machine
# !pip install tensorflow-gpu
# !pip install tensorflow-datasets

# tenorflow
import tensorflow as     tf
from   tensorflow import keras

# tensorflow datasets
import tensorflow_datasets as tfds

# additional libraries
import math
import numpy             as np
import matplotlib.pyplot as plt
# %matplotlib inline

# version check
# print(tf.__version__)

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# data
DATA_NUM_CLASSES        = 10
DATA_CHANNELS           = 3
DATA_ROWS               = 32
DATA_COLS               = 32
DATA_CROP_ROWS          = 28
DATA_CROP_COLS          = 28
DATA_MEAN               = np.array([[[125.30691805, 122.95039414, 113.86538318]]]) # CIFAR10
DATA_STD_DEV            = np.array([[[ 62.99321928,  62.08870764,  66.70489964]]]) # CIFAR10

# model
MODEL_LEVEL_0_BLOCKS    = 18

# training
TRAINING_BATCH_SIZE      = 32
TRAINING_SHUFFLE_BUFFER  = 5000
TRAINING_BN_MOMENTUM     = 0.99
TRAINING_BN_EPSILON      = 0.001
TRAINING_LR_MAX          = 0.001
TRAINING_LR_INIT_SCALE   = 0.01
TRAINING_LR_INIT_EPOCHS  = 5
TRAINING_LR_FINAL_SCALE  = 0.01
TRAINING_LR_FINAL_EPOCHS = 55

# training (derived)
TRAINING_NUM_EPOCHS = TRAINING_LR_INIT_EPOCHS + TRAINING_LR_FINAL_EPOCHS
TRAINING_LR_INIT    = TRAINING_LR_MAX*TRAINING_LR_INIT_SCALE
TRAINING_LR_FINAL   = TRAINING_LR_MAX*TRAINING_LR_FINAL_SCALE

# saving
SAVE_MODEL_PATH = './save/model/'
# !mkdir -p "$SAVE_MODEL_PATH"

# %%
# pre processing for training data
def pre_processing_train(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]
  
    # image is cast to float32, normalized, augmented and random cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_crop(image, size=[DATA_CROP_ROWS, DATA_CROP_COLS, 3])
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# pre processing for testing data
def pre_processing_test(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]

    # image is cast to float32, normalized, augmented and center cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.crop_to_bounding_box(image, (DATA_ROWS - DATA_CROP_ROWS) // 2, (DATA_COLS - DATA_CROP_COLS) // 2, DATA_CROP_ROWS, DATA_CROP_COLS)
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# %%
# download data and split into training and testing datasets
dataset_train, info = tfds.load("cifar10", split=tfds.Split.TRAIN, with_info=True)
dataset_test,  info = tfds.load("cifar10", split=tfds.Split.TEST,  with_info=True)

dataset_train
# Out:
# Downloading and preparing dataset cifar10/3.0.0 (download: 162.17 MiB, generated: Unknown size, total: 162.17 MiB) to /root/tensorflow_datasets/cifar10/3.0.0...
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Completed...', max=1, style=ProgressStyl…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Size...', max=1, style=ProgressStyle(des…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Extraction completed...', max=1, style=Prog…
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.0.incompleteSOZJ0W/cifar10-train.tfrecord
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.0.incompleteSOZJ0W/cifar10-test.tfrecord
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.0. Subsequent calls will reuse this data.
# <DatasetV1Adapter shapes: {image: (32, 32, 3), label: ()}, types: {image: tf.uint8, label: tf.int64}>

# %%
# transform training dataset
dataset_train = dataset_train.map(pre_processing_train, num_parallel_calls=4)
dataset_train = dataset_train.shuffle(buffer_size=TRAINING_SHUFFLE_BUFFER)
dataset_train = dataset_train.batch(TRAINING_BATCH_SIZE)
dataset_train = dataset_train.prefetch(buffer_size=1)

# %%
# transform testing dataset
dataset_test = dataset_test.map(pre_processing_test, num_parallel_calls=4)
dataset_test = dataset_test.batch(TRAINING_BATCH_SIZE)
dataset_test = dataset_test.prefetch(buffer_size=1)

# %%
# create and compile model
def create_model(rows, cols, channels, level_0_blocks, num_classes, lr_initial):

    # encoder - input
    model_input = keras.Input(shape=(rows, cols, channels), name='input_image')
    x           = model_input
    
    # encoder - tail
    x = keras.layers.Conv2D(16, 3, strides=1, padding='same', activation=None, use_bias=False)(x)

    # encoder - level 0 - special bottleneck - repeat 1x
    # input
    #    tensor: 28 x 28 x 16
    # residual path
    #    filter: 256 x 1 x 1 x 16
    #    filter: 3 x 3 x 3 x 1536
    #    filter: 64 x 1 x 1 x 1536
    # main path
    #    filter: 64 x 1 x 1 x 16
    # output
    #    tensor: 28 x 28 x 64
    residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(x)
    residual = tf.nn.relu6(residual)
    residual = keras.layers.Conv2D(256, 1, strides=1, padding='same', activation=None, use_bias=False)(residual)

    residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(residual)
    residual = tf.nn.relu6(residual)
    residual = keras.layers.DepthwiseConv2D(3, strides=1, padding='same', activation=None, use_bias=False, depth_multiplier=6)(residual)

    residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(residual)
    residual = tf.nn.relu6(residual)
    residual = keras.layers.Conv2D(64, 1, strides=1, padding='same', activation=None, use_bias=False)(residual)

    x        = keras.layers.Conv2D(64, 1, strides=1, padding='same', activation=None, use_bias=False)(x)
    x        = keras.layers.Add()([x, residual])

    # encoder - level 0 - residual bottleneck layer (bottleneck depth-separable convolution with residuals) - repeat 19x
    # input
    #    tensor: 28 x 28 x 16
    # residual path
    #    filter: 256 x 1 x 1 x 16
    #    filter: 3 x 3 x 3 x 1536
    #    filter: 64 x 1 x 1 x 1536
    # main path
    #    filter: 64 x 1 x 1 x 16
    # output
    #    tensor: 28 x 28 x 64
    for n0 in range(level_0_blocks - 1):
      # Expansion
      residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(x)
      residual = tf.nn.relu6(residual)
      residual = keras.layers.Conv2D(256, 1, strides=1, padding='same', activation=None, use_bias=False)(residual)


      # Depthwise Separable Convolution
      residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(residual)
      residual = tf.nn.relu6(residual)
      residual = keras.layers.DepthwiseConv2D(3, strides=1, padding='same', activation=None, use_bias=False, depth_multiplier=6)(residual)

      # Projection
      residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(residual)
      residual = tf.nn.relu6(residual)
      residual = keras.layers.Conv2D(64, 1, strides=1, padding='same', activation=None, use_bias=False)(residual)
      # x        = keras.layers.Conv2D(64, 1, strides=1, padding='same', activation=None, use_bias=False)(x)
      x        = keras.layers.Add()([x, residual])

    # encoder - output
    encoder_output = x

    # decoder
    y              = keras.layers.GlobalAveragePooling2D()(encoder_output)
    decoder_output = keras.layers.Dense(num_classes, activation='softmax')(y)

    # forward path
    model = keras.Model(inputs=model_input, outputs=decoder_output, name='resnetv2_model')

    # loss, backward path (implicit) and weight update
    model.compile(optimizer=tf.keras.optimizers.Adam(lr_initial), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # return model
    return model

# %%
# create and compile model
model = create_model(DATA_CROP_ROWS, DATA_CROP_COLS, DATA_CHANNELS, MODEL_LEVEL_0_BLOCKS, DATA_NUM_CLASSES, TRAINING_LR_MAX)
model

# %%
# model description and figure
model.summary()
keras.utils.plot_model(model, 'cifar_model.png', show_shapes=True)
# Out:
# Model: "resnetv2_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 28, 28, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 16)   432         input_image[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 28, 28, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6 (TensorFlowOp [(None, 28, 28, 16)] 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 256)  4096        tf_op_layer_Relu6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 28, 28, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_1 (TensorFlow [(None, 28, 28, 256) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 28, 28, 1536) 6144        depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_2 (TensorFlow [(None, 28, 28, 1536 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 64)   1024        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 64)   98304       tf_op_layer_Relu6_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 28, 28, 64)   0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 28, 28, 64)   256         add[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_3 (TensorFlow [(None, 28, 28, 64)] 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 256)  16384       tf_op_layer_Relu6_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 28, 28, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_4 (TensorFlow [(None, 28, 28, 256) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 28, 28, 1536) 6144        depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_5 (TensorFlow [(None, 28, 28, 1536 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 64)   98304       tf_op_layer_Relu6_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 64)   0           add[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 28, 28, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_6 (TensorFlow [(None, 28, 28, 64)] 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 256)  16384       tf_op_layer_Relu6_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 256)  1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_7 (TensorFlow [(None, 28, 28, 256) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 1536) 6144        depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_8 (TensorFlow [(None, 28, 28, 1536 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 64)   98304       tf_op_layer_Relu6_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 64)   0           add_1[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 28, 28, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_9 (TensorFlow [(None, 28, 28, 64)] 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 256)  16384       tf_op_layer_Relu6_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_10 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_11 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 64)   98304       tf_op_layer_Relu6_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 64)   0           add_2[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 28, 28, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_12 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 28, 28, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_13 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_14 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 64)   0           add_3[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 64)   256         add_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_15 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_16 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_17 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 64)   0           add_4[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 64)   256         add_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_18 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_19 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_20 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 64)   0           add_5[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_21 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_22 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_23 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 64)   0           add_6[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 64)   256         add_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_24 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 256)  1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_25 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_26 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_26[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 28, 28, 64)   0           add_7[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 28, 28, 64)   256         add_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_27 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 28, 28, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_28 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_29 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_29[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 28, 28, 64)   0           add_8[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 28, 28, 64)   256         add_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_30 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 28, 28, 256)  1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_31 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_32 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_32[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 28, 28, 64)   0           add_9[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 28, 28, 64)   256         add_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_33 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 28, 28, 256)  1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_34 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_35 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_35[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 28, 28, 64)   0           add_10[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 28, 28, 64)   256         add_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_36 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 28, 28, 256)  1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_37 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_38 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_38[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 28, 28, 64)   0           add_11[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 28, 28, 64)   256         add_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_39 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 28, 28, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_40 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_41 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_41[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 28, 28, 64)   0           add_12[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 28, 28, 64)   256         add_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_42 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 28, 28, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_43 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_44 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_44[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 28, 28, 64)   0           add_13[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 28, 28, 64)   256         add_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_45 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 28, 28, 256)  1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_46 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_47 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_47[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 28, 28, 64)   0           add_14[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 28, 28, 64)   256         add_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_48 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 28, 28, 256)  1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_49 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_50 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_50[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 28, 28, 64)   0           add_15[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 28, 28, 64)   256         add_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_51 (TensorFlo [(None, 28, 28, 64)] 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 28, 28, 256)  16384       tf_op_layer_Relu6_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 28, 28, 256)  1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_52 (TensorFlo [(None, 28, 28, 256) 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 28, 28, 1536) 13824       tf_op_layer_Relu6_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 28, 28, 1536) 6144        depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_53 (TensorFlo [(None, 28, 28, 1536 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 28, 28, 64)   98304       tf_op_layer_Relu6_53[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 28, 28, 64)   0           add_16[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 64)           0           add_17[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           650         global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 2,436,474
# Trainable params: 2,369,754
# Non-trainable params: 66,720
# __________________________________________________________________________________________________

# %%
# learning rate schedule
def lr_schedule(epoch):

    # staircase
    # lr = TRAINING_LR_MAX*math.pow(TRAINING_LR_SCALE, math.floor(epoch/TRAINING_LR_EPOCHS))

    # linear warmup followed by cosine decay
    if epoch < TRAINING_LR_INIT_EPOCHS:
        lr = (TRAINING_LR_MAX - TRAINING_LR_INIT)*(float(epoch)/TRAINING_LR_INIT_EPOCHS) + TRAINING_LR_INIT
    else:
        lr = (TRAINING_LR_MAX - TRAINING_LR_FINAL)*max(0.0, math.cos(((float(epoch) - TRAINING_LR_INIT_EPOCHS)/(TRAINING_LR_FINAL_EPOCHS - 1.0))*(math.pi/2.0))) + TRAINING_LR_FINAL

    # debug - learning rate display
    # print(epoch)
    # print(lr)

    return lr

# plot training accuracy and loss curves
def plot_training_curves(history):

    # training and validation data accuracy
    acc     = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    # training and validation data loss
    loss     = history.history['loss']
    val_loss = history.history['val_loss']

    # plot accuracy
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()), 1])
    plt.title('Training and Validation Accuracy')

    # plot loss
    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0, 2.0])
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()

# %%
# callbacks (learning rate schedule, model checkpointing during training)
callbacks = [keras.callbacks.LearningRateScheduler(lr_schedule),
             keras.callbacks.ModelCheckpoint(filepath=SAVE_MODEL_PATH+'model_{epoch}.h5', save_best_only=True, monitor='val_loss', verbose=1)]

# %%
# training
initial_epoch_num = 0
history           = model.fit(x=dataset_train, epochs=TRAINING_NUM_EPOCHS, verbose=1, callbacks=callbacks, validation_data=dataset_test, initial_epoch=initial_epoch_num)
# Out:
# Epoch 1/60
# 1563/1563 [==============================] - ETA: 0s - loss: 1.7406 - accuracy: 0.3650
# Epoch 00001: val_loss improved from inf to 1.51789, saving model to ./save/model/model_1.h5
# 1563/1563 [==============================] - 919s 588ms/step - loss: 1.7406 - accuracy: 0.3650 - val_loss: 1.5179 - val_accuracy: 0.4451 - lr: 1.0000e-05
# Epoch 2/60
# 1563/1563 [==============================] - ETA: 0s - loss: 1.7009 - accuracy: 0.4580
# Epoch 00002: val_loss improved from 1.51789 to 1.35219, saving model to ./save/model/model_2.h5
# 1563/1563 [==============================] - 919s 588ms/step - loss: 1.7009 - accuracy: 0.4580 - val_loss: 1.3522 - val_accuracy: 0.5403 - lr: 2.0800e-04
# Epoch 3/60
#  956/1563 [=================>............] - ETA: 5:42 - loss: 1.5221 - accuracy: 0.5204

# %%
# plot accuracy and loss curves
plot_training_curves(history)

# %%
# extract a batch from the testing dataset
# then extract images and labels for this batch
dataset_display                = dataset_test.take(1)
it                             = iter(dataset_display)
display_images, display_labels = next(it)

# %%
# predict pmf and labels for this dataset
predict_labels_pmf = model.predict(x=dataset_display)
predict_labels     = np.argmax(predict_labels_pmf, axis=1)

# %%
# for display normalize images to [0, 1]
display_images = ((display_images*DATA_STD_DEV.reshape((1, 1, 1, 3))) + DATA_MEAN.reshape((1, 1, 1, 3)))/255.0;

# %%
# cycle through the images in the batch
for image_index in range(predict_labels.size):
    
    # display the predicted label, actual label and image
    print('Predicted label: {0:1d} and actual label: {1:1d}'.format(predict_labels[image_index], display_labels[image_index]))
    plt.imshow(display_images[image_index, :, :, :])
    plt.show()
