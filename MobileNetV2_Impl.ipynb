# %% [markdown]
# <a href="https://colab.research.google.com/github/mcsantiago/MobileNetV2-Impl/blob/master/MobileNetV2_Impl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# select tensorflow 2 in colab
# %tensorflow_version 2.x

# install tensorflow 2 and tensorflow datasets on a personal machine
# !pip install tensorflow-gpu
# !pip install tensorflow-datasets

# tenorflow
import tensorflow as     tf
from   tensorflow import keras

# tensorflow datasets
import tensorflow_datasets as tfds

# additional libraries
import math
import numpy             as np
import matplotlib.pyplot as plt
# %matplotlib inline

# version check
# print(tf.__version__)

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# data
DATA_NUM_CLASSES        = 10
DATA_CHANNELS           = 3
DATA_ROWS               = 32
DATA_COLS               = 32
DATA_CROP_ROWS          = 28
DATA_CROP_COLS          = 28
DATA_MEAN               = np.array([[[125.30691805, 122.95039414, 113.86538318]]]) # CIFAR10
DATA_STD_DEV            = np.array([[[ 62.99321928,  62.08870764,  66.70489964]]]) # CIFAR10

# model
MODEL_LEVEL_0_BLOCKS    = 18

# training
TRAINING_BATCH_SIZE      = 32
TRAINING_SHUFFLE_BUFFER  = 5000
TRAINING_BN_MOMENTUM     = 0.99
TRAINING_BN_EPSILON      = 0.001
TRAINING_LR_MAX          = 0.001
TRAINING_LR_INIT_SCALE   = 0.01
TRAINING_LR_INIT_EPOCHS  = 5
TRAINING_LR_FINAL_SCALE  = 0.01
TRAINING_LR_FINAL_EPOCHS = 25

# training (derived)
TRAINING_NUM_EPOCHS = TRAINING_LR_INIT_EPOCHS + TRAINING_LR_FINAL_EPOCHS
TRAINING_LR_INIT    = TRAINING_LR_MAX*TRAINING_LR_INIT_SCALE
TRAINING_LR_FINAL   = TRAINING_LR_MAX*TRAINING_LR_FINAL_SCALE

# saving
SAVE_MODEL_PATH = './save/model/'
# !mkdir -p "$SAVE_MODEL_PATH"

# %%
# pre processing for training data
def pre_processing_train(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]
  
    # image is cast to float32, normalized, augmented and random cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_crop(image, size=[DATA_CROP_ROWS, DATA_CROP_COLS, 3])
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# pre processing for testing data
def pre_processing_test(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]

    # image is cast to float32, normalized, augmented and center cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.crop_to_bounding_box(image, (DATA_ROWS - DATA_CROP_ROWS) // 2, (DATA_COLS - DATA_CROP_COLS) // 2, DATA_CROP_ROWS, DATA_CROP_COLS)
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# %%
# download data and split into training and testing datasets
dataset_train, info = tfds.load("cifar10", split=tfds.Split.TRAIN, with_info=True)
dataset_test,  info = tfds.load("cifar10", split=tfds.Split.TEST,  with_info=True)

dataset_train
# Out:
# Downloading and preparing dataset cifar10/3.0.0 (download: 162.17 MiB, generated: Unknown size, total: 162.17 MiB) to /root/tensorflow_datasets/cifar10/3.0.0...
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Completed...', max=1, style=ProgressStyl…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Size...', max=1, style=ProgressStyle(des…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Extraction completed...', max=1, style=Prog…
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.0.incompleteE636P2/cifar10-train.tfrecord
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10/3.0.0.incompleteE636P2/cifar10-test.tfrecord
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.0. Subsequent calls will reuse this data.
# <DatasetV1Adapter shapes: {image: (32, 32, 3), label: ()}, types: {image: tf.uint8, label: tf.int64}>

# %%
# transform training dataset
dataset_train = dataset_train.map(pre_processing_train, num_parallel_calls=4)
dataset_train = dataset_train.shuffle(buffer_size=TRAINING_SHUFFLE_BUFFER)
dataset_train = dataset_train.batch(TRAINING_BATCH_SIZE)
dataset_train = dataset_train.prefetch(buffer_size=1)

# %%
# transform testing dataset
dataset_test = dataset_test.map(pre_processing_test, num_parallel_calls=4)
dataset_test = dataset_test.batch(TRAINING_BATCH_SIZE)
dataset_test = dataset_test.prefetch(buffer_size=1)

# %%
def bottleneck_block(k, t, c, n, s, x, padding='same'):
    """ Bottleneck block with:
          k input channels
          t expension
          c output channels
          n levels
          s strides on the first level
          x input layer
    """
    for n0 in range(n):
      residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(x)
      residual = tf.nn.relu6(residual)
      residual = keras.layers.Conv2D(k, 1, strides=1, padding='same', activation=None, use_bias=False)(residual)

      residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(residual)
      residual = tf.nn.relu6(residual)
      residual = keras.layers.DepthwiseConv2D(3, strides=1, padding='same', activation=None, use_bias=False, depth_multiplier=t)(residual)

      residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(residual)
      residual = tf.nn.relu6(residual)
      residual = keras.layers.Conv2D(c, 1, strides=1, padding='same', activation=None, use_bias=False)(residual)

      x        = keras.layers.Conv2D(c, 1, strides=1, padding='same', activation=None, use_bias=False)(x)
      x        = keras.layers.Add()([x, residual])
    return x

# create and compile model
def create_model(rows, cols, channels, level_0_blocks, num_classes, lr_initial):
    # encoder - input
    model_input = keras.Input(shape=(rows, cols, channels), name='input_image')
    x           = model_input
    
    # encoder - tail
    x = keras.layers.Conv2D(32, 3, strides=2, padding='same', activation=None, use_bias=False)(x)

    x = bottleneck_block(32, 1, 16, 1, 1, x)
    x = bottleneck_block(16, 6, 24, 2, 2, x)
    x = bottleneck_block(24, 6, 32, 3, 2, x)
    x = bottleneck_block(32, 6, 64, 4, 2, x)
    x = bottleneck_block(64, 6, 96, 3, 1, x)
    x = bottleneck_block(96, 6, 160, 3, 2, x)
    x = bottleneck_block(96, 6, 320, 1, 1, x)

    x = keras.layers.Conv2D(1280, 1, strides=1, padding='valid', activation='relu', use_bias=False)(x)

    # encoder - output
    encoder_output = x

    # decoder
    y              = keras.layers.GlobalAveragePooling2D()(encoder_output)
    decoder_output = keras.layers.Dense(num_classes, activation='softmax')(y)

    # forward path
    model = keras.Model(inputs=model_input, outputs=decoder_output, name='resnetv2_model')

    # loss, backward path (implicit) and weight update
    model.compile(optimizer=tf.keras.optimizers.Adam(lr_initial), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # return model
    return model

# %%
# create and compile model
model = create_model(DATA_CROP_ROWS, DATA_CROP_COLS, DATA_CHANNELS, MODEL_LEVEL_0_BLOCKS, DATA_NUM_CLASSES, TRAINING_LR_MAX)

# model description and figure
model.summary()
keras.utils.plot_model(model, 'cifar_model.png', show_shapes=True)
# Out:
# Model: "resnetv2_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 28, 28, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 14, 14, 32)   864         input_image[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 14, 14, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6 (TensorFlowOp [(None, 14, 14, 32)] 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 14, 14, 32)   1024        tf_op_layer_Relu6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 14, 14, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_1 (TensorFlow [(None, 14, 14, 32)] 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 14, 14, 32)   288         tf_op_layer_Relu6_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 14, 14, 32)   128         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_2 (TensorFlow [(None, 14, 14, 32)] 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 16)   512         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 16)   512         tf_op_layer_Relu6_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 14, 14, 16)   0           conv2d_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 14, 14, 16)   64          add[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_3 (TensorFlow [(None, 14, 14, 16)] 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 14, 14, 16)   256         tf_op_layer_Relu6_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 14, 14, 16)   64          conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_4 (TensorFlow [(None, 14, 14, 16)] 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 14, 14, 96)   864         tf_op_layer_Relu6_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 14, 14, 96)   384         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_5 (TensorFlow [(None, 14, 14, 96)] 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 14, 14, 24)   384         add[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 24)   2304        tf_op_layer_Relu6_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 14, 14, 24)   0           conv2d_6[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 14, 14, 24)   96          add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_6 (TensorFlow [(None, 14, 14, 24)] 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 14, 14, 16)   384         tf_op_layer_Relu6_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 14, 14, 16)   64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_7 (TensorFlow [(None, 14, 14, 16)] 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 14, 14, 96)   864         tf_op_layer_Relu6_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 14, 14, 96)   384         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_8 (TensorFlow [(None, 14, 14, 96)] 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 24)   576         add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 14, 14, 24)   2304        tf_op_layer_Relu6_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 14, 14, 24)   0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 24)   96          add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_9 (TensorFlow [(None, 14, 14, 24)] 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 24)   576         tf_op_layer_Relu6_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 24)   96          conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_10 (TensorFlo [(None, 14, 14, 24)] 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 14, 14, 144)  1296        tf_op_layer_Relu6_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 14, 14, 144)  576         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_11 (TensorFlo [(None, 14, 14, 144) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 32)   768         add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 14, 14, 32)   4608        tf_op_layer_Relu6_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 14, 32)   0           conv2d_12[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 14, 14, 32)   128         add_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_12 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 24)   768         tf_op_layer_Relu6_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 24)   96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_13 (TensorFlo [(None, 14, 14, 24)] 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 14, 14, 144)  1296        tf_op_layer_Relu6_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 144)  576         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_14 (TensorFlo [(None, 14, 14, 144) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 32)   1024        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 32)   4608        tf_op_layer_Relu6_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 32)   0           conv2d_15[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 14, 14, 32)   128         add_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_15 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 24)   768         tf_op_layer_Relu6_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 14, 14, 24)   96          conv2d_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_16 (TensorFlo [(None, 14, 14, 24)] 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 14, 14, 144)  1296        tf_op_layer_Relu6_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 14, 14, 144)  576         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_17 (TensorFlo [(None, 14, 14, 144) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 32)   1024        add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 32)   4608        tf_op_layer_Relu6_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 32)   0           conv2d_18[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 14, 14, 32)   128         add_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_18 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 32)   1024        tf_op_layer_Relu6_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 14, 14, 32)   128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_19 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 14, 14, 192)  1728        tf_op_layer_Relu6_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 14, 14, 192)  768         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_20 (TensorFlo [(None, 14, 14, 192) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 64)   2048        add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 64)   12288       tf_op_layer_Relu6_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 14, 14, 64)   0           conv2d_21[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 14, 14, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_21 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 32)   2048        tf_op_layer_Relu6_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 14, 14, 32)   128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_22 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 14, 14, 192)  1728        tf_op_layer_Relu6_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 14, 14, 192)  768         depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_23 (TensorFlo [(None, 14, 14, 192) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 64)   4096        add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 64)   12288       tf_op_layer_Relu6_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 64)   0           conv2d_24[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 14, 14, 64)   256         add_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_24 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 32)   2048        tf_op_layer_Relu6_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 14, 14, 32)   128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_25 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 14, 14, 192)  1728        tf_op_layer_Relu6_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 192)  768         depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_26 (TensorFlo [(None, 14, 14, 192) 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 64)   4096        add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 64)   12288       tf_op_layer_Relu6_26[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 64)   0           conv2d_27[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 14, 14, 64)   256         add_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_27 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 32)   2048        tf_op_layer_Relu6_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 14, 14, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_28 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 14, 14, 192)  1728        tf_op_layer_Relu6_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 14, 14, 192)  768         depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_29 (TensorFlo [(None, 14, 14, 192) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 64)   4096        add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 64)   12288       tf_op_layer_Relu6_29[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 64)   0           conv2d_30[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 14, 14, 64)   256         add_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_30 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 64)   4096        tf_op_layer_Relu6_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 14, 14, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_31 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 14, 14, 384)  3456        tf_op_layer_Relu6_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 14, 14, 384)  1536        depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_32 (TensorFlo [(None, 14, 14, 384) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 96)   6144        add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 96)   36864       tf_op_layer_Relu6_32[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 96)   0           conv2d_33[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 14, 14, 96)   384         add_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_33 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 64)   6144        tf_op_layer_Relu6_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 14, 14, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_34 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 14, 14, 384)  3456        tf_op_layer_Relu6_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 14, 14, 384)  1536        depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_35 (TensorFlo [(None, 14, 14, 384) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 96)   9216        add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 96)   36864       tf_op_layer_Relu6_35[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 96)   0           conv2d_36[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 14, 14, 96)   384         add_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_36 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 64)   6144        tf_op_layer_Relu6_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 14, 14, 64)   256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_37 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 14, 14, 384)  3456        tf_op_layer_Relu6_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 14, 14, 384)  1536        depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_38 (TensorFlo [(None, 14, 14, 384) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 96)   9216        add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 96)   36864       tf_op_layer_Relu6_38[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 96)   0           conv2d_39[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 14, 14, 96)   384         add_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_39 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 96)   9216        tf_op_layer_Relu6_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 14, 14, 96)   384         conv2d_40[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_40 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 14, 14, 576)  5184        tf_op_layer_Relu6_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 14, 14, 576)  2304        depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_41 (TensorFlo [(None, 14, 14, 576) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 160)  15360       add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 160)  92160       tf_op_layer_Relu6_41[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 160)  0           conv2d_42[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 14, 14, 160)  640         add_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_42 (TensorFlo [(None, 14, 14, 160) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 96)   15360       tf_op_layer_Relu6_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 14, 14, 96)   384         conv2d_43[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_43 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 14, 14, 576)  5184        tf_op_layer_Relu6_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 14, 14, 576)  2304        depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_44 (TensorFlo [(None, 14, 14, 576) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 160)  25600       add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 160)  92160       tf_op_layer_Relu6_44[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 14, 14, 160)  0           conv2d_45[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 14, 14, 160)  640         add_14[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_45 (TensorFlo [(None, 14, 14, 160) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 96)   15360       tf_op_layer_Relu6_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 14, 14, 96)   384         conv2d_46[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_46 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 14, 14, 576)  5184        tf_op_layer_Relu6_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 14, 14, 576)  2304        depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_47 (TensorFlo [(None, 14, 14, 576) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 14, 14, 160)  25600       add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 14, 14, 160)  92160       tf_op_layer_Relu6_47[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 14, 14, 160)  0           conv2d_48[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 14, 14, 160)  640         add_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_48 (TensorFlo [(None, 14, 14, 160) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 14, 14, 96)   15360       tf_op_layer_Relu6_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 14, 14, 96)   384         conv2d_49[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_49 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 14, 14, 576)  5184        tf_op_layer_Relu6_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 14, 14, 576)  2304        depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_50 (TensorFlo [(None, 14, 14, 576) 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 14, 14, 320)  51200       add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 14, 14, 320)  184320      tf_op_layer_Relu6_50[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 14, 14, 320)  0           conv2d_51[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 14, 14, 1280) 409600      add_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           12810       global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 1,378,010
# Trainable params: 1,364,138
# Non-trainable params: 13,872
# __________________________________________________________________________________________________

# %%
# learning rate schedule
def lr_schedule(epoch):

    # staircase
    # lr = TRAINING_LR_MAX*math.pow(TRAINING_LR_SCALE, math.floor(epoch/TRAINING_LR_EPOCHS))

    # linear warmup followed by cosine decay
    if epoch < TRAINING_LR_INIT_EPOCHS:
        lr = (TRAINING_LR_MAX - TRAINING_LR_INIT)*(float(epoch)/TRAINING_LR_INIT_EPOCHS) + TRAINING_LR_INIT
    else:
        lr = (TRAINING_LR_MAX - TRAINING_LR_FINAL)*max(0.0, math.cos(((float(epoch) - TRAINING_LR_INIT_EPOCHS)/(TRAINING_LR_FINAL_EPOCHS - 1.0))*(math.pi/2.0))) + TRAINING_LR_FINAL

    # debug - learning rate display
    # print(epoch)
    # print(lr)

    return lr

# plot training accuracy and loss curves
def plot_training_curves(history):

    # training and validation data accuracy
    acc     = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    # training and validation data loss
    loss     = history.history['loss']
    val_loss = history.history['val_loss']

    # plot accuracy
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()), 1])
    plt.title('Training and Validation Accuracy')

    # plot loss
    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0, 2.0])
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()

# %%
# callbacks (learning rate schedule, model checkpointing during training)
callbacks = [keras.callbacks.LearningRateScheduler(lr_schedule),
             keras.callbacks.ModelCheckpoint(filepath=SAVE_MODEL_PATH+'model_{epoch}.h5', save_best_only=True, monitor='val_loss', verbose=1)]

# %%
# training
initial_epoch_num = 0
with tf.device('/device:GPU:0'):
  history           = model.fit(x=dataset_train, epochs=TRAINING_NUM_EPOCHS, verbose=1, callbacks=callbacks, validation_data=dataset_test, initial_epoch=initial_epoch_num)
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - ETA: 0s - loss: 1.9359 - accuracy: 0.2810
# Epoch 00001: val_loss improved from inf to 1.74966, saving model to ./save/model/model_1.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 1.9359 - accuracy: 0.2810 - val_loss: 1.7497 - val_accuracy: 0.3506 - lr: 1.0000e-05
# Epoch 2/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.6170 - accuracy: 0.4020
# Epoch 00002: val_loss improved from 1.74966 to 1.43770, saving model to ./save/model/model_2.h5
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.6169 - accuracy: 0.4020 - val_loss: 1.4377 - val_accuracy: 0.4749 - lr: 2.0800e-04
# Epoch 3/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.3778 - accuracy: 0.5053
# Epoch 00003: val_loss improved from 1.43770 to 1.31856, saving model to ./save/model/model_3.h5
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.3779 - accuracy: 0.5053 - val_loss: 1.3186 - val_accuracy: 0.5266 - lr: 4.0600e-04
# Epoch 4/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.2241 - accuracy: 0.5654
# Epoch 00004: val_loss did not improve from 1.31856
# 1563/1563 [==============================] - 93s 60ms/step - loss: 1.2239 - accuracy: 0.5654 - val_loss: 1.4665 - val_accuracy: 0.5343 - lr: 6.0400e-04
# Epoch 5/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.1158 - accuracy: 0.6049
# Epoch 00005: val_loss did not improve from 1.31856
# 1563/1563 [==============================] - 93s 60ms/step - loss: 1.1162 - accuracy: 0.6049 - val_loss: 1.3389 - val_accuracy: 0.5838 - lr: 8.0200e-04
# Epoch 6/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.0250 - accuracy: 0.6405
# Epoch 00006: val_loss improved from 1.31856 to 1.06955, saving model to ./save/model/model_6.h5
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.0248 - accuracy: 0.6405 - val_loss: 1.0695 - val_accuracy: 0.6290 - lr: 0.0010
# Epoch 7/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.9110 - accuracy: 0.6817
# Epoch 00007: val_loss improved from 1.06955 to 0.88322, saving model to ./save/model/model_7.h5
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.9110 - accuracy: 0.6817 - val_loss: 0.8832 - val_accuracy: 0.6861 - lr: 9.9788e-04
# Epoch 8/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.8399 - accuracy: 0.7068
# Epoch 00008: val_loss did not improve from 0.88322
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.8400 - accuracy: 0.7068 - val_loss: 0.8836 - val_accuracy: 0.6934 - lr: 9.9153e-04
# Epoch 9/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7792 - accuracy: 0.7309
# Epoch 00009: val_loss improved from 0.88322 to 0.80933, saving model to ./save/model/model_9.h5
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.7791 - accuracy: 0.7309 - val_loss: 0.8093 - val_accuracy: 0.7135 - lr: 9.8098e-04
# Epoch 10/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7364 - accuracy: 0.7452
# Epoch 00010: val_loss improved from 0.80933 to 0.77441, saving model to ./save/model/model_10.h5
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.7365 - accuracy: 0.7452 - val_loss: 0.7744 - val_accuracy: 0.7400 - lr: 9.6627e-04
# Epoch 11/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6991 - accuracy: 0.7594
# Epoch 00011: val_loss did not improve from 0.77441
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.6993 - accuracy: 0.7594 - val_loss: 0.8123 - val_accuracy: 0.7391 - lr: 9.4746e-04
# Epoch 12/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6554 - accuracy: 0.7748
# Epoch 00012: val_loss improved from 0.77441 to 0.74612, saving model to ./save/model/model_12.h5
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.6556 - accuracy: 0.7747 - val_loss: 0.7461 - val_accuracy: 0.7463 - lr: 9.2464e-04
# Epoch 13/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6232 - accuracy: 0.7851
# Epoch 00013: val_loss did not improve from 0.74612
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.6231 - accuracy: 0.7852 - val_loss: 0.7751 - val_accuracy: 0.7336 - lr: 8.9790e-04
# Epoch 14/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5917 - accuracy: 0.7960
# Epoch 00014: val_loss improved from 0.74612 to 0.63317, saving model to ./save/model/model_14.h5
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.5920 - accuracy: 0.7960 - val_loss: 0.6332 - val_accuracy: 0.7814 - lr: 8.6737e-04
# Epoch 15/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5635 - accuracy: 0.8061
# Epoch 00015: val_loss improved from 0.63317 to 0.63299, saving model to ./save/model/model_15.h5
# 1563/1563 [==============================] - 93s 59ms/step - loss: 0.5635 - accuracy: 0.8061 - val_loss: 0.6330 - val_accuracy: 0.7852 - lr: 8.3315e-04
# Epoch 16/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5367 - accuracy: 0.8160
# Epoch 00016: val_loss improved from 0.63299 to 0.58489, saving model to ./save/model/model_16.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.5365 - accuracy: 0.8160 - val_loss: 0.5849 - val_accuracy: 0.8047 - lr: 7.9542e-04
# Epoch 17/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5115 - accuracy: 0.8225
# Epoch 00017: val_loss did not improve from 0.58489
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.5113 - accuracy: 0.8226 - val_loss: 0.6334 - val_accuracy: 0.7842 - lr: 7.5432e-04
# Epoch 18/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4825 - accuracy: 0.8330
# Epoch 00018: val_loss improved from 0.58489 to 0.52856, saving model to ./save/model/model_18.h5
# 1563/1563 [==============================] - 96s 61ms/step - loss: 0.4824 - accuracy: 0.8330 - val_loss: 0.5286 - val_accuracy: 0.8201 - lr: 7.1004e-04
# Epoch 19/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4555 - accuracy: 0.8444
# Epoch 00019: val_loss did not improve from 0.52856
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.4556 - accuracy: 0.8444 - val_loss: 0.5396 - val_accuracy: 0.8168 - lr: 6.6275e-04
# Epoch 20/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4297 - accuracy: 0.8504
# Epoch 00020: val_loss improved from 0.52856 to 0.50103, saving model to ./save/model/model_20.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.4297 - accuracy: 0.8504 - val_loss: 0.5010 - val_accuracy: 0.8279 - lr: 6.1267e-04
# Epoch 21/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.3963 - accuracy: 0.8616
# Epoch 00021: val_loss improved from 0.50103 to 0.45072, saving model to ./save/model/model_21.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.3965 - accuracy: 0.8616 - val_loss: 0.4507 - val_accuracy: 0.8449 - lr: 5.6001e-04
# Epoch 22/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.3701 - accuracy: 0.8711
# Epoch 00022: val_loss improved from 0.45072 to 0.44762, saving model to ./save/model/model_22.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.3702 - accuracy: 0.8711 - val_loss: 0.4476 - val_accuracy: 0.8478 - lr: 5.0500e-04
# Epoch 23/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.3410 - accuracy: 0.8814
# Epoch 00023: val_loss improved from 0.44762 to 0.42648, saving model to ./save/model/model_23.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.3410 - accuracy: 0.8814 - val_loss: 0.4265 - val_accuracy: 0.8525 - lr: 4.4787e-04
# Epoch 24/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.3110 - accuracy: 0.8924
# Epoch 00024: val_loss improved from 0.42648 to 0.41245, saving model to ./save/model/model_24.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.3112 - accuracy: 0.8923 - val_loss: 0.4124 - val_accuracy: 0.8655 - lr: 3.8886e-04
# Epoch 25/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2863 - accuracy: 0.9003
# Epoch 00025: val_loss improved from 0.41245 to 0.37241, saving model to ./save/model/model_25.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.2863 - accuracy: 0.9003 - val_loss: 0.3724 - val_accuracy: 0.8757 - lr: 3.2823e-04
# Epoch 26/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2524 - accuracy: 0.9114
# Epoch 00026: val_loss improved from 0.37241 to 0.36165, saving model to ./save/model/model_26.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.2523 - accuracy: 0.9114 - val_loss: 0.3617 - val_accuracy: 0.8808 - lr: 2.6623e-04
# Epoch 27/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2239 - accuracy: 0.9203
# Epoch 00027: val_loss improved from 0.36165 to 0.34719, saving model to ./save/model/model_27.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.2239 - accuracy: 0.9203 - val_loss: 0.3472 - val_accuracy: 0.8850 - lr: 2.0314e-04
# Epoch 28/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1945 - accuracy: 0.9319
# Epoch 00028: val_loss improved from 0.34719 to 0.34684, saving model to ./save/model/model_28.h5
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.1945 - accuracy: 0.9319 - val_loss: 0.3468 - val_accuracy: 0.8916 - lr: 1.3922e-04
# Epoch 29/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1679 - accuracy: 0.9413
# Epoch 00029: val_loss improved from 0.34684 to 0.34286, saving model to ./save/model/model_29.h5
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.1678 - accuracy: 0.9413 - val_loss: 0.3429 - val_accuracy: 0.8903 - lr: 7.4749e-05
# Epoch 30/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9482
# Epoch 00030: val_loss improved from 0.34286 to 0.32377, saving model to ./save/model/model_30.h5
# 1563/1563 [==============================] - 93s 60ms/step - loss: 0.1496 - accuracy: 0.9482 - val_loss: 0.3238 - val_accuracy: 0.8962 - lr: 1.0000e-05

# %%
# plot accuracy and loss curves
plot_training_curves(history)

# %%
# extract a batch from the testing dataset
# then extract images and labels for this batch
dataset_display                = dataset_test.take(1)
it                             = iter(dataset_display)
display_images, display_labels = next(it)

# %%
# predict pmf and labels for this dataset
predict_labels_pmf = model.predict(x=dataset_display)
predict_labels     = np.argmax(predict_labels_pmf, axis=1)

# %%
# for display normalize images to [0, 1]
display_images = ((display_images*DATA_STD_DEV.reshape((1, 1, 1, 3))) + DATA_MEAN.reshape((1, 1, 1, 3)))/255.0;

# %%
# cycle through the images in the batch
for image_index in range(predict_labels.size):
    
    # display the predicted label, actual label and image
    print('Predicted label: {0:1d} and actual label: {1:1d}'.format(predict_labels[image_index], display_labels[image_index]))
    plt.imshow(display_images[image_index, :, :, :])
    plt.show()
# Out:
# Predicted label: 5 and actual label: 7
# Predicted label: 0 and actual label: 0
# Predicted label: 6 and actual label: 6
# Predicted label: 9 and actual label: 9
# Predicted label: 5 and actual label: 5
# Predicted label: 1 and actual label: 1
# Predicted label: 7 and actual label: 7
# Predicted label: 0 and actual label: 0
# Predicted label: 5 and actual label: 3
# Predicted label: 2 and actual label: 2
# Predicted label: 7 and actual label: 7
# Predicted label: 2 and actual label: 2
# Predicted label: 7 and actual label: 7
# Predicted label: 9 and actual label: 9
# Predicted label: 6 and actual label: 6
# Predicted label: 8 and actual label: 8
# Predicted label: 8 and actual label: 8
# Predicted label: 8 and actual label: 8
# Predicted label: 7 and actual label: 7
# Predicted label: 9 and actual label: 9
# Predicted label: 4 and actual label: 4
# Predicted label: 2 and actual label: 2
# Predicted label: 3 and actual label: 3
# Predicted label: 5 and actual label: 5
# Predicted label: 0 and actual label: 0
# Predicted label: 0 and actual label: 0
# Predicted label: 2 and actual label: 2
# Predicted label: 8 and actual label: 8
# Predicted label: 1 and actual label: 1
# Predicted label: 8 and actual label: 8
# Predicted label: 2 and actual label: 2
# Predicted label: 0 and actual label: 0
