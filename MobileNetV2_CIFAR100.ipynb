# %% [markdown]
# <a href="https://colab.research.google.com/github/mcsantiago/MobileNetV2-Impl/blob/master/MobileNetV2_CIFAR100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# select tensorflow 2 in colab
# %tensorflow_version 2.x

# install tensorflow 2 and tensorflow datasets on a personal machine
# !pip install tensorflow-gpu
# !pip install tensorflow-datasets

# tenorflow
import tensorflow as     tf
from   tensorflow import keras

# tensorflow datasets
import tensorflow_datasets as tfds

# additional libraries
import math
import numpy             as np
import matplotlib.pyplot as plt
# %matplotlib inline

# version check
# print(tf.__version__)

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# data
DATA_NUM_CLASSES        = 100
DATA_CHANNELS           = 3
DATA_ROWS               = 32
DATA_COLS               = 32
DATA_CROP_ROWS          = 28
DATA_CROP_COLS          = 28
DATA_MEAN               = np.array([[[125.30691805, 122.95039414, 113.86538318]]]) # CIFAR10
DATA_STD_DEV            = np.array([[[ 62.99321928,  62.08870764,  66.70489964]]]) # CIFAR10

# model
MODEL_LEVEL_0_BLOCKS    = 18

# training
TRAINING_BATCH_SIZE      = 32
TRAINING_SHUFFLE_BUFFER  = 5000
TRAINING_BN_MOMENTUM     = 0.99
TRAINING_BN_EPSILON      = 0.001
TRAINING_LR_MAX          = 0.001
TRAINING_LR_INIT_SCALE   = 0.01
TRAINING_LR_INIT_EPOCHS  = 5
TRAINING_LR_FINAL_SCALE  = 0.01
TRAINING_LR_FINAL_EPOCHS = 25

# training (derived)
TRAINING_NUM_EPOCHS = TRAINING_LR_INIT_EPOCHS + TRAINING_LR_FINAL_EPOCHS
TRAINING_LR_INIT    = TRAINING_LR_MAX*TRAINING_LR_INIT_SCALE
TRAINING_LR_FINAL   = TRAINING_LR_MAX*TRAINING_LR_FINAL_SCALE

# saving
SAVE_MODEL_PATH = './save/model/'
# !mkdir -p "$SAVE_MODEL_PATH"

# %%
# pre processing for training data
def pre_processing_train(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]
  
    # image is cast to float32, normalized, augmented and random cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_crop(image, size=[DATA_CROP_ROWS, DATA_CROP_COLS, 3])
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# pre processing for testing data
def pre_processing_test(example):

    # extract image and label from example
    image = example["image"]
    label = example["label"]

    # image is cast to float32, normalized, augmented and center cropped
    # label is cast to int32
    image = tf.math.divide(tf.math.subtract(tf.dtypes.cast(image, tf.float32), DATA_MEAN), DATA_STD_DEV)
    image = tf.image.crop_to_bounding_box(image, (DATA_ROWS - DATA_CROP_ROWS) // 2, (DATA_COLS - DATA_CROP_COLS) // 2, DATA_CROP_ROWS, DATA_CROP_COLS)
    label = tf.dtypes.cast(label, tf.int32)
    
    # return image and label
    return image, label

# %%
# download data and split into training and testing datasets
dataset_train, info = tfds.load("cifar100", split=tfds.Split.TRAIN, with_info=True)
dataset_test,  info = tfds.load("cifar100", split=tfds.Split.TEST,  with_info=True)

dataset_train
# Out:
# Downloading and preparing dataset cifar100/3.0.0 (download: 160.71 MiB, generated: Unknown size, total: 160.71 MiB) to /root/tensorflow_datasets/cifar100/3.0.0...
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Completed...', max=1, style=ProgressStyl…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Dl Size...', max=1, style=ProgressStyle(des…
# HBox(children=(IntProgress(value=1, bar_style='info', description='Extraction completed...', max=1, style=Prog…
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar100/3.0.0.incompleteBEDI18/cifar100-train.tfrecord
# HBox(children=(IntProgress(value=0, max=50000), HTML(value='')))
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cifar100/3.0.0.incompleteBEDI18/cifar100-test.tfrecord
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# Dataset cifar100 downloaded and prepared to /root/tensorflow_datasets/cifar100/3.0.0. Subsequent calls will reuse this data.
# <DatasetV1Adapter shapes: {coarse_label: (), image: (32, 32, 3), label: ()}, types: {coarse_label: tf.int64, image: tf.uint8, label: tf.int64}>

# %%
# transform training dataset
dataset_train = dataset_train.map(pre_processing_train, num_parallel_calls=4)
dataset_train = dataset_train.shuffle(buffer_size=TRAINING_SHUFFLE_BUFFER)
dataset_train = dataset_train.batch(TRAINING_BATCH_SIZE)
dataset_train = dataset_train.prefetch(buffer_size=1)

# %%
# transform testing dataset
dataset_test = dataset_test.map(pre_processing_test, num_parallel_calls=4)
dataset_test = dataset_test.batch(TRAINING_BATCH_SIZE)
dataset_test = dataset_test.prefetch(buffer_size=1)

# %%
def bottleneck_block(k, t, c, n, s, x, padding='same'):
    """ Bottleneck block with:
          k input channels
          t expension
          c output channels
          n levels
          s strides on the first level
          x input layer
    """
    for n0 in range(n):
      residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(x)
      residual = tf.nn.relu6(residual)
      residual = keras.layers.Conv2D(k, 1, strides=1, padding='same', activation=None, use_bias=False)(residual)

      residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(residual)
      residual = tf.nn.relu6(residual)
      residual = keras.layers.DepthwiseConv2D(3, strides=1, padding='same', activation=None, use_bias=False, depth_multiplier=t)(residual)

      residual = keras.layers.BatchNormalization(axis=-1, momentum=TRAINING_BN_MOMENTUM, epsilon=TRAINING_BN_EPSILON, center=True, scale=True)(residual)
      residual = tf.nn.relu6(residual)
      residual = keras.layers.Conv2D(c, 1, strides=1, padding='same', activation=None, use_bias=False)(residual)

      x        = keras.layers.Conv2D(c, 1, strides=1, padding='same', activation=None, use_bias=False)(x)
      x        = keras.layers.Add()([x, residual])
    return x

# create and compile model
def create_model(rows, cols, channels, level_0_blocks, num_classes, lr_initial):
    # encoder - input
    model_input = keras.Input(shape=(rows, cols, channels), name='input_image')
    x           = model_input
    
    # encoder - tail
    x = keras.layers.Conv2D(32, 3, strides=2, padding='same', activation=None, use_bias=False)(x)

    x = bottleneck_block(32, 1, 16, 1, 1, x)
    x = bottleneck_block(16, 6, 24, 2, 2, x)
    x = bottleneck_block(24, 6, 32, 3, 2, x)
    x = bottleneck_block(32, 6, 64, 4, 2, x)
    x = bottleneck_block(64, 6, 96, 3, 1, x)
    x = bottleneck_block(96, 6, 160, 3, 2, x)
    x = bottleneck_block(96, 6, 320, 1, 1, x)

    x = keras.layers.Conv2D(1280, 1, strides=1, padding='valid', activation='relu', use_bias=False)(x)

    # encoder - output
    encoder_output = x

    # decoder
    y              = keras.layers.GlobalAveragePooling2D()(encoder_output)
    decoder_output = keras.layers.Dense(num_classes, activation='softmax')(y)

    # forward path
    model = keras.Model(inputs=model_input, outputs=decoder_output, name='resnetv2_model')

    # loss, backward path (implicit) and weight update
    model.compile(optimizer=tf.keras.optimizers.Adam(lr_initial), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # return model
    return model

# %%
# create and compile model
model = create_model(DATA_CROP_ROWS, DATA_CROP_COLS, DATA_CHANNELS, MODEL_LEVEL_0_BLOCKS, DATA_NUM_CLASSES, TRAINING_LR_MAX)

# model description and figure
model.summary()
keras.utils.plot_model(model, 'cifar_model.png', show_shapes=True)
# Out:
# Model: "resnetv2_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 28, 28, 3)]  0
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 14, 14, 32)   864         input_image[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 14, 14, 32)   128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_51 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 14, 14, 32)   1024        tf_op_layer_Relu6_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 14, 14, 32)   128         conv2d_54[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_52 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_17 (DepthwiseC (None, 14, 14, 32)   288         tf_op_layer_Relu6_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 14, 14, 32)   128         depthwise_conv2d_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_53 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 14, 14, 16)   512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 16)   512         tf_op_layer_Relu6_53[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 14, 14, 16)   0           conv2d_56[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 14, 14, 16)   64          add_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_54 (TensorFlo [(None, 14, 14, 16)] 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 14, 14, 16)   256         tf_op_layer_Relu6_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 14, 14, 16)   64          conv2d_57[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_55 (TensorFlo [(None, 14, 14, 16)] 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_18 (DepthwiseC (None, 14, 14, 96)   864         tf_op_layer_Relu6_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 14, 14, 96)   384         depthwise_conv2d_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_56 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 14, 14, 24)   384         add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 14, 14, 24)   2304        tf_op_layer_Relu6_56[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 14, 14, 24)   0           conv2d_59[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 14, 14, 24)   96          add_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_57 (TensorFlo [(None, 14, 14, 24)] 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 14, 14, 16)   384         tf_op_layer_Relu6_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 14, 14, 16)   64          conv2d_60[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_58 (TensorFlo [(None, 14, 14, 16)] 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_19 (DepthwiseC (None, 14, 14, 96)   864         tf_op_layer_Relu6_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 14, 14, 96)   384         depthwise_conv2d_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_59 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 14, 14, 24)   576         add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 14, 14, 24)   2304        tf_op_layer_Relu6_59[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 14, 14, 24)   0           conv2d_62[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 14, 14, 24)   96          add_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_60 (TensorFlo [(None, 14, 14, 24)] 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 14, 14, 24)   576         tf_op_layer_Relu6_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 14, 14, 24)   96          conv2d_63[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_61 (TensorFlo [(None, 14, 14, 24)] 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_20 (DepthwiseC (None, 14, 14, 144)  1296        tf_op_layer_Relu6_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 14, 14, 144)  576         depthwise_conv2d_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_62 (TensorFlo [(None, 14, 14, 144) 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 14, 14, 32)   768         add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 14, 14, 32)   4608        tf_op_layer_Relu6_62[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 14, 14, 32)   0           conv2d_65[0][0]
#                                                                  conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 14, 14, 32)   128         add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_63 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 14, 14, 24)   768         tf_op_layer_Relu6_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 14, 14, 24)   96          conv2d_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_64 (TensorFlo [(None, 14, 14, 24)] 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_21 (DepthwiseC (None, 14, 14, 144)  1296        tf_op_layer_Relu6_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 14, 14, 144)  576         depthwise_conv2d_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_65 (TensorFlo [(None, 14, 14, 144) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 14, 14, 32)   1024        add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 14, 14, 32)   4608        tf_op_layer_Relu6_65[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 14, 14, 32)   0           conv2d_68[0][0]
#                                                                  conv2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 14, 14, 32)   128         add_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_66 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 14, 14, 24)   768         tf_op_layer_Relu6_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 14, 14, 24)   96          conv2d_69[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_67 (TensorFlo [(None, 14, 14, 24)] 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_22 (DepthwiseC (None, 14, 14, 144)  1296        tf_op_layer_Relu6_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 14, 14, 144)  576         depthwise_conv2d_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_68 (TensorFlo [(None, 14, 14, 144) 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 14, 14, 32)   1024        add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 14, 14, 32)   4608        tf_op_layer_Relu6_68[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 14, 14, 32)   0           conv2d_71[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 14, 14, 32)   128         add_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_69 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 14, 14, 32)   1024        tf_op_layer_Relu6_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 14, 14, 32)   128         conv2d_72[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_70 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_23 (DepthwiseC (None, 14, 14, 192)  1728        tf_op_layer_Relu6_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 14, 14, 192)  768         depthwise_conv2d_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_71 (TensorFlo [(None, 14, 14, 192) 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 14, 14, 64)   2048        add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 14, 14, 64)   12288       tf_op_layer_Relu6_71[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 14, 14, 64)   0           conv2d_74[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 14, 14, 64)   256         add_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_72 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 14, 14, 32)   2048        tf_op_layer_Relu6_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 14, 14, 32)   128         conv2d_75[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_73 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_24 (DepthwiseC (None, 14, 14, 192)  1728        tf_op_layer_Relu6_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 14, 14, 192)  768         depthwise_conv2d_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_74 (TensorFlo [(None, 14, 14, 192) 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 14, 14, 64)   4096        add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 14, 14, 64)   12288       tf_op_layer_Relu6_74[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 14, 14, 64)   0           conv2d_77[0][0]
#                                                                  conv2d_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 14, 14, 64)   256         add_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_75 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 14, 14, 32)   2048        tf_op_layer_Relu6_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 14, 14, 32)   128         conv2d_78[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_76 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_25 (DepthwiseC (None, 14, 14, 192)  1728        tf_op_layer_Relu6_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 14, 14, 192)  768         depthwise_conv2d_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_77 (TensorFlo [(None, 14, 14, 192) 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 14, 14, 64)   4096        add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 14, 14, 64)   12288       tf_op_layer_Relu6_77[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 14, 14, 64)   0           conv2d_80[0][0]
#                                                                  conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 14, 14, 64)   256         add_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_78 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 14, 14, 32)   2048        tf_op_layer_Relu6_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 14, 14, 32)   128         conv2d_81[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_79 (TensorFlo [(None, 14, 14, 32)] 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_26 (DepthwiseC (None, 14, 14, 192)  1728        tf_op_layer_Relu6_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 14, 14, 192)  768         depthwise_conv2d_26[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_80 (TensorFlo [(None, 14, 14, 192) 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 14, 14, 64)   4096        add_25[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 14, 14, 64)   12288       tf_op_layer_Relu6_80[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 14, 14, 64)   0           conv2d_83[0][0]
#                                                                  conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 14, 14, 64)   256         add_26[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_81 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 14, 14, 64)   4096        tf_op_layer_Relu6_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 14, 14, 64)   256         conv2d_84[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_82 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_27 (DepthwiseC (None, 14, 14, 384)  3456        tf_op_layer_Relu6_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 14, 14, 384)  1536        depthwise_conv2d_27[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_83 (TensorFlo [(None, 14, 14, 384) 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 14, 14, 96)   6144        add_26[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 14, 14, 96)   36864       tf_op_layer_Relu6_83[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 14, 14, 96)   0           conv2d_86[0][0]
#                                                                  conv2d_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 14, 14, 96)   384         add_27[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_84 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 14, 14, 64)   6144        tf_op_layer_Relu6_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 14, 14, 64)   256         conv2d_87[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_85 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_28 (DepthwiseC (None, 14, 14, 384)  3456        tf_op_layer_Relu6_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 14, 14, 384)  1536        depthwise_conv2d_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_86 (TensorFlo [(None, 14, 14, 384) 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 14, 14, 96)   9216        add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 14, 14, 96)   36864       tf_op_layer_Relu6_86[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 14, 14, 96)   0           conv2d_89[0][0]
#                                                                  conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 14, 14, 96)   384         add_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_87 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 14, 14, 64)   6144        tf_op_layer_Relu6_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 14, 14, 64)   256         conv2d_90[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_88 (TensorFlo [(None, 14, 14, 64)] 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_29 (DepthwiseC (None, 14, 14, 384)  3456        tf_op_layer_Relu6_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 14, 14, 384)  1536        depthwise_conv2d_29[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_89 (TensorFlo [(None, 14, 14, 384) 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 14, 14, 96)   9216        add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 14, 14, 96)   36864       tf_op_layer_Relu6_89[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 14, 14, 96)   0           conv2d_92[0][0]
#                                                                  conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 14, 14, 96)   384         add_29[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_90 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 14, 14, 96)   9216        tf_op_layer_Relu6_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 14, 14, 96)   384         conv2d_93[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_91 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_30 (DepthwiseC (None, 14, 14, 576)  5184        tf_op_layer_Relu6_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 14, 14, 576)  2304        depthwise_conv2d_30[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_92 (TensorFlo [(None, 14, 14, 576) 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 14, 14, 160)  15360       add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 14, 14, 160)  92160       tf_op_layer_Relu6_92[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 14, 14, 160)  0           conv2d_95[0][0]
#                                                                  conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 14, 14, 160)  640         add_30[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_93 (TensorFlo [(None, 14, 14, 160) 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 14, 14, 96)   15360       tf_op_layer_Relu6_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 14, 14, 96)   384         conv2d_96[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_94 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_31 (DepthwiseC (None, 14, 14, 576)  5184        tf_op_layer_Relu6_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 14, 14, 576)  2304        depthwise_conv2d_31[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_95 (TensorFlo [(None, 14, 14, 576) 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 14, 14, 160)  25600       add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 14, 14, 160)  92160       tf_op_layer_Relu6_95[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 14, 14, 160)  0           conv2d_98[0][0]
#                                                                  conv2d_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 14, 14, 160)  640         add_31[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_96 (TensorFlo [(None, 14, 14, 160) 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 14, 14, 96)   15360       tf_op_layer_Relu6_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 14, 14, 96)   384         conv2d_99[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_97 (TensorFlo [(None, 14, 14, 96)] 0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_32 (DepthwiseC (None, 14, 14, 576)  5184        tf_op_layer_Relu6_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 14, 14, 576)  2304        depthwise_conv2d_32[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_98 (TensorFlo [(None, 14, 14, 576) 0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 14, 14, 160)  25600       add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 14, 14, 160)  92160       tf_op_layer_Relu6_98[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 14, 14, 160)  0           conv2d_101[0][0]
#                                                                  conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 14, 14, 160)  640         add_32[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_99 (TensorFlo [(None, 14, 14, 160) 0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 14, 14, 96)   15360       tf_op_layer_Relu6_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 14, 14, 96)   384         conv2d_102[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_100 (TensorFl [(None, 14, 14, 96)] 0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_33 (DepthwiseC (None, 14, 14, 576)  5184        tf_op_layer_Relu6_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 14, 14, 576)  2304        depthwise_conv2d_33[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Relu6_101 (TensorFl [(None, 14, 14, 576) 0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 14, 14, 320)  51200       add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 14, 14, 320)  184320      tf_op_layer_Relu6_101[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 14, 14, 320)  0           conv2d_104[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 14, 14, 1280) 409600      add_33[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1280)         0           conv2d_105[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          128100      global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 1,493,300
# Trainable params: 1,479,428
# Non-trainable params: 13,872
# __________________________________________________________________________________________________

# %%
# learning rate schedule
def lr_schedule(epoch):

    # staircase
    # lr = TRAINING_LR_MAX*math.pow(TRAINING_LR_SCALE, math.floor(epoch/TRAINING_LR_EPOCHS))

    # linear warmup followed by cosine decay
    if epoch < TRAINING_LR_INIT_EPOCHS:
        lr = (TRAINING_LR_MAX - TRAINING_LR_INIT)*(float(epoch)/TRAINING_LR_INIT_EPOCHS) + TRAINING_LR_INIT
    else:
        lr = (TRAINING_LR_MAX - TRAINING_LR_FINAL)*max(0.0, math.cos(((float(epoch) - TRAINING_LR_INIT_EPOCHS)/(TRAINING_LR_FINAL_EPOCHS - 1.0))*(math.pi/2.0))) + TRAINING_LR_FINAL

    return lr

# plot training accuracy and loss curves
def plot_training_curves(history):

    # training and validation data accuracy
    acc     = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    # training and validation data loss
    loss     = history.history['loss']
    val_loss = history.history['val_loss']

    # plot accuracy
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()), 1])
    plt.title('Training and Validation Accuracy')

    # plot loss
    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0, 2.0])
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()

# %%
# callbacks (learning rate schedule, model checkpointing during training)
callbacks = [keras.callbacks.LearningRateScheduler(lr_schedule),
             keras.callbacks.ModelCheckpoint(filepath=SAVE_MODEL_PATH+'model_{epoch}.h5', save_best_only=True, monitor='val_loss', verbose=1)]

# %%
# training
initial_epoch_num = 0
with tf.device('/device:GPU:0'):
  history           = model.fit(x=dataset_train, epochs=TRAINING_NUM_EPOCHS, verbose=1, callbacks=callbacks, validation_data=dataset_test, initial_epoch=initial_epoch_num)
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - ETA: 0s - loss: 4.3057 - accuracy: 0.0499
# Epoch 00001: val_loss improved from inf to 4.07975, saving model to ./save/model/model_1.h5
# 1563/1563 [==============================] - 98s 62ms/step - loss: 4.3057 - accuracy: 0.0499 - val_loss: 4.0797 - val_accuracy: 0.0731 - lr: 1.0000e-05
# Epoch 2/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 3.8100 - accuracy: 0.1143
# Epoch 00002: val_loss improved from 4.07975 to 3.47590, saving model to ./save/model/model_2.h5
# 1563/1563 [==============================] - 96s 62ms/step - loss: 3.8100 - accuracy: 0.1143 - val_loss: 3.4759 - val_accuracy: 0.1601 - lr: 2.0800e-04
# Epoch 3/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 3.3685 - accuracy: 0.1854
# Epoch 00003: val_loss improved from 3.47590 to 3.23926, saving model to ./save/model/model_3.h5
# 1563/1563 [==============================] - 97s 62ms/step - loss: 3.3684 - accuracy: 0.1854 - val_loss: 3.2393 - val_accuracy: 0.2102 - lr: 4.0600e-04
# Epoch 4/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 3.0340 - accuracy: 0.2473
# Epoch 00004: val_loss improved from 3.23926 to 3.10285, saving model to ./save/model/model_4.h5
# 1563/1563 [==============================] - 96s 61ms/step - loss: 3.0337 - accuracy: 0.2473 - val_loss: 3.1028 - val_accuracy: 0.2404 - lr: 6.0400e-04
# Epoch 5/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 2.7728 - accuracy: 0.3004
# Epoch 00005: val_loss improved from 3.10285 to 2.64346, saving model to ./save/model/model_5.h5
# 1563/1563 [==============================] - 96s 61ms/step - loss: 2.7728 - accuracy: 0.3003 - val_loss: 2.6435 - val_accuracy: 0.3245 - lr: 8.0200e-04
# Epoch 6/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 2.5554 - accuracy: 0.3452
# Epoch 00006: val_loss did not improve from 2.64346
# 1563/1563 [==============================] - 96s 61ms/step - loss: 2.5550 - accuracy: 0.3452 - val_loss: 2.6512 - val_accuracy: 0.3287 - lr: 0.0010
# Epoch 7/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 2.3196 - accuracy: 0.3984
# Epoch 00007: val_loss improved from 2.64346 to 2.55090, saving model to ./save/model/model_7.h5
# 1563/1563 [==============================] - 97s 62ms/step - loss: 2.3199 - accuracy: 0.3983 - val_loss: 2.5509 - val_accuracy: 0.3580 - lr: 9.9788e-04
# Epoch 8/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 2.1196 - accuracy: 0.4413
# Epoch 00008: val_loss improved from 2.55090 to 2.24255, saving model to ./save/model/model_8.h5
# 1563/1563 [==============================] - 97s 62ms/step - loss: 2.1193 - accuracy: 0.4414 - val_loss: 2.2426 - val_accuracy: 0.4223 - lr: 9.9153e-04
# Epoch 9/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.9729 - accuracy: 0.4742
# Epoch 00009: val_loss improved from 2.24255 to 2.04311, saving model to ./save/model/model_9.h5
# 1563/1563 [==============================] - 96s 61ms/step - loss: 1.9726 - accuracy: 0.4742 - val_loss: 2.0431 - val_accuracy: 0.4606 - lr: 9.8098e-04
# Epoch 10/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.8333 - accuracy: 0.5091
# Epoch 00010: val_loss improved from 2.04311 to 2.01438, saving model to ./save/model/model_10.h5
# 1563/1563 [==============================] - 97s 62ms/step - loss: 1.8334 - accuracy: 0.5091 - val_loss: 2.0144 - val_accuracy: 0.4681 - lr: 9.6627e-04
# Epoch 11/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.7286 - accuracy: 0.5305
# Epoch 00011: val_loss improved from 2.01438 to 1.91721, saving model to ./save/model/model_11.h5
# 1563/1563 [==============================] - 98s 63ms/step - loss: 1.7283 - accuracy: 0.5306 - val_loss: 1.9172 - val_accuracy: 0.5052 - lr: 9.4746e-04
# Epoch 12/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.6313 - accuracy: 0.5546
# Epoch 00012: val_loss improved from 1.91721 to 1.85563, saving model to ./save/model/model_12.h5
# 1563/1563 [==============================] - 98s 63ms/step - loss: 1.6313 - accuracy: 0.5546 - val_loss: 1.8556 - val_accuracy: 0.5158 - lr: 9.2464e-04
# Epoch 13/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.5258 - accuracy: 0.5772
# Epoch 00013: val_loss did not improve from 1.85563
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.5257 - accuracy: 0.5773 - val_loss: 1.9211 - val_accuracy: 0.5081 - lr: 8.9790e-04
# Epoch 14/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.4360 - accuracy: 0.6024
# Epoch 00014: val_loss improved from 1.85563 to 1.84220, saving model to ./save/model/model_14.h5
# 1563/1563 [==============================] - 95s 60ms/step - loss: 1.4362 - accuracy: 0.6023 - val_loss: 1.8422 - val_accuracy: 0.5212 - lr: 8.6737e-04
# Epoch 15/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.3482 - accuracy: 0.6214
# Epoch 00015: val_loss did not improve from 1.84220
# 1563/1563 [==============================] - 95s 61ms/step - loss: 1.3479 - accuracy: 0.6214 - val_loss: 1.9663 - val_accuracy: 0.5035 - lr: 8.3315e-04
# Epoch 16/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.2658 - accuracy: 0.6424
# Epoch 00016: val_loss improved from 1.84220 to 1.59366, saving model to ./save/model/model_16.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 1.2659 - accuracy: 0.6424 - val_loss: 1.5937 - val_accuracy: 0.5764 - lr: 7.9542e-04
# Epoch 17/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.1773 - accuracy: 0.6627
# Epoch 00017: val_loss did not improve from 1.59366
# 1563/1563 [==============================] - 94s 60ms/step - loss: 1.1772 - accuracy: 0.6627 - val_loss: 1.6309 - val_accuracy: 0.5882 - lr: 7.5432e-04
# Epoch 18/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.1048 - accuracy: 0.6818
# Epoch 00018: val_loss did not improve from 1.59366
# 1563/1563 [==============================] - 95s 61ms/step - loss: 1.1045 - accuracy: 0.6818 - val_loss: 1.6147 - val_accuracy: 0.5848 - lr: 7.1004e-04
# Epoch 19/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 1.0242 - accuracy: 0.7021
# Epoch 00019: val_loss did not improve from 1.59366
# 1563/1563 [==============================] - 95s 61ms/step - loss: 1.0252 - accuracy: 0.7020 - val_loss: 1.6306 - val_accuracy: 0.5896 - lr: 6.6275e-04
# Epoch 20/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.9386 - accuracy: 0.7241
# Epoch 00020: val_loss improved from 1.59366 to 1.56643, saving model to ./save/model/model_20.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.9387 - accuracy: 0.7240 - val_loss: 1.5664 - val_accuracy: 0.6027 - lr: 6.1267e-04
# Epoch 21/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.8572 - accuracy: 0.7457
# Epoch 00021: val_loss did not improve from 1.56643
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.8573 - accuracy: 0.7457 - val_loss: 1.5869 - val_accuracy: 0.6079 - lr: 5.6001e-04
# Epoch 22/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.7788 - accuracy: 0.7664
# Epoch 00022: val_loss did not improve from 1.56643
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.7787 - accuracy: 0.7664 - val_loss: 1.5868 - val_accuracy: 0.6132 - lr: 5.0500e-04
# Epoch 23/30
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7022 - accuracy: 0.7889
# Epoch 00023: val_loss improved from 1.56643 to 1.53669, saving model to ./save/model/model_23.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.7022 - accuracy: 0.7889 - val_loss: 1.5367 - val_accuracy: 0.6270 - lr: 4.4787e-04
# Epoch 24/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.6211 - accuracy: 0.8109
# Epoch 00024: val_loss did not improve from 1.53669
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.6208 - accuracy: 0.8110 - val_loss: 1.5793 - val_accuracy: 0.6356 - lr: 3.8886e-04
# Epoch 25/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.5455 - accuracy: 0.8319
# Epoch 00025: val_loss did not improve from 1.53669
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.5454 - accuracy: 0.8319 - val_loss: 1.5729 - val_accuracy: 0.6384 - lr: 3.2823e-04
# Epoch 26/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.4737 - accuracy: 0.8521
# Epoch 00026: val_loss improved from 1.53669 to 1.53010, saving model to ./save/model/model_26.h5
# 1563/1563 [==============================] - 94s 60ms/step - loss: 0.4738 - accuracy: 0.8520 - val_loss: 1.5301 - val_accuracy: 0.6491 - lr: 2.6623e-04
# Epoch 27/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.3963 - accuracy: 0.8737
# Epoch 00027: val_loss improved from 1.53010 to 1.51258, saving model to ./save/model/model_27.h5
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.3965 - accuracy: 0.8736 - val_loss: 1.5126 - val_accuracy: 0.6619 - lr: 2.0314e-04
# Epoch 28/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.3395 - accuracy: 0.8920
# Epoch 00028: val_loss did not improve from 1.51258
# 1563/1563 [==============================] - 95s 61ms/step - loss: 0.3395 - accuracy: 0.8921 - val_loss: 1.5288 - val_accuracy: 0.6701 - lr: 1.3922e-04
# Epoch 29/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2829 - accuracy: 0.9111
# Epoch 00029: val_loss did not improve from 1.51258
# 1563/1563 [==============================] - 96s 62ms/step - loss: 0.2829 - accuracy: 0.9111 - val_loss: 1.5476 - val_accuracy: 0.6749 - lr: 7.4749e-05
# Epoch 30/30
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.2478 - accuracy: 0.9226
# Epoch 00030: val_loss did not improve from 1.51258
# 1563/1563 [==============================] - 99s 63ms/step - loss: 0.2478 - accuracy: 0.9226 - val_loss: 1.5260 - val_accuracy: 0.6777 - lr: 1.0000e-05

# %%
# plot accuracy and loss curves
plot_training_curves(history)

# %%
# extract a batch from the testing dataset
# then extract images and labels for this batch
dataset_display                = dataset_test.take(1)
it                             = iter(dataset_display)
display_images, display_labels = next(it)

# %%
# predict pmf and labels for this dataset
predict_labels_pmf = model.predict(x=dataset_display)
predict_labels     = np.argmax(predict_labels_pmf, axis=1)

# %%
# for display normalize images to [0, 1]
display_images = ((display_images*DATA_STD_DEV.reshape((1, 1, 1, 3))) + DATA_MEAN.reshape((1, 1, 1, 3)))/255.0;

# %%
# cycle through the images in the batch
for image_index in range(predict_labels.size):
    
    # display the predicted label, actual label and image
    print('Predicted label: {0:1d} and actual label: {1:1d}'.format(predict_labels[image_index], display_labels[image_index]))
    plt.imshow(display_images[image_index, :, :, :])
    plt.show()
# Out:
# Predicted label: 33 and actual label: 43
# Predicted label: 59 and actual label: 59
# Predicted label: 10 and actual label: 10
# Predicted label: 98 and actual label: 31
# Predicted label: 52 and actual label: 52
# Predicted label: 16 and actual label: 16
# Predicted label: 81 and actual label: 81
# Predicted label: 5 and actual label: 5
# Predicted label: 47 and actual label: 47
# Predicted label: 62 and actual label: 62
# Predicted label: 18 and actual label: 14
# Predicted label: 79 and actual label: 79
# Predicted label: 56 and actual label: 7
# Predicted label: 15 and actual label: 34
# Predicted label: 40 and actual label: 69
# Predicted label: 14 and actual label: 14
# Predicted label: 76 and actual label: 76
# Predicted label: 15 and actual label: 85
# Predicted label: 40 and actual label: 18
# Predicted label: 53 and actual label: 53
# Predicted label: 24 and actual label: 24
# Predicted label: 0 and actual label: 0
# Predicted label: 46 and actual label: 46
# Predicted label: 1 and actual label: 1
# Predicted label: 31 and actual label: 31
# Predicted label: 3 and actual label: 3
# Predicted label: 19 and actual label: 19
# Predicted label: 54 and actual label: 6
# Predicted label: 52 and actual label: 52
# Predicted label: 54 and actual label: 54
# Predicted label: 26 and actual label: 26
# Predicted label: 72 and actual label: 72
